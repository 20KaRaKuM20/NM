# %% [markdown]
# <a href="https://colab.research.google.com/github/20KaRaKuM20/NM/blob/main/%D0%BB%D1%8012_%D0%92%D0%B8%D1%81%D0%BE%D1%86%D1%8C%D0%BA%D0%B8%D0%B9_%D0%92%D0%BE%D0%BB%D0%BE%D0%B4%D0%B8%D0%BC%D0%B8%D1%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Обчислення інтегралу методом трапецій
from scipy import integrate
import numpy as np

def f(x):
    return 1 / np.sqrt(2 * x**2 + 1.6)

# Задаємо межі інтегрування (від 0.15 до 0.5)
a = 0.15
b = 0.5
n = 10

# Обчислюємо значення інтегралу методом трапецій
def trapezoidal_rule(f, a, b, n):
    h = (b - a) / n
    total_sum = 0.5 * (f(a) + f(b))
    x = a

    for i in range(1, n):
        x += h
        total_sum += f(x)

    integral = h * total_sum
    return integral

# Виводимо результат
integral = trapezoidal_rule(f, a, b, n)
print("Trapetzia method result:", round(integral, 5))

# Перевірка
v, err = integrate.quad(f, a, b)
print("Check with SciPy quad method:", round(v, 5))
# Out:
# Trapetzia method result: 0.25909
# Check with SciPy quad method: 0.25911

# %%
#Обчислення інтеграла методом прямокутників
from scipy import integrate
import numpy as np

# Межі інтегрування з картинки
a = 1.0
b = 2.0
n = 10
h = (b - a) / n

def f1(x):
    return 1 / np.sqrt(2 * x**2 + 1.3)

# Метод лівих прямокутників
def left_rec(f1, a, b):
    sum_val = 0
    for i in range(0, n):
        sum_val += f1(a + i * h)
    return sum_val * h

print("Left rectangle:", round(left_rec(f1, a, b), 5))

# Метод правих прямокутників
def right_rec(f1, a, b):
    sum_val = 0
    for i in range(1, n + 1):
        sum_val += f1(a + i * h)
    return sum_val * h

print("Right rectangle:", round(right_rec(f1, a, b), 5))

# Метод середніх прямокутників
def aver_rec(f1, a, b):
    sum_val = 0
    for i in range(0, n):
        sum_val += f1(a + (i + 0.5) * h)
    return sum_val * h

print("Average rectangle:", round(aver_rec(f1, a, b), 5))

# Перевірка за допомогою функції scipy
v, err = integrate.quad(f1, a, b)
print("Check with SciPy quad method:", round(v, 5))
# Out:
# Left rectangle: 0.43448
# Right rectangle: 0.41223
# Average rectangle: 0.42312
# Check with SciPy quad method: 0.4232

# %%
#Обчислення інтеграла методом Симпсона
from scipy import integrate
import numpy as np

def f(x):
    return np.tan(x**2) / (x**2 + 1)

# Задаємо межі інтегрування (від 0.2 до 1)
a = 0.2
b = 1.0
n = 8
h = (b - a) / n

# Обчислюємо значення інтегралу методом Симпсона
def simpson_rule(f, a, b, n):
    integr = f(a) + f(b)
    for i in range(1, n):
        k = a + i*h
        if i % 2 == 0:
            integr += 2 * f(k)
        else:
            integr += 4 * f(k)
    integr *= h/3
    return integr

# Виводимо результат
print("Simpsone method:", round(simpson_rule(f, a, b, n), 3))

# Перевірка за допомогою вбудованої функції
v, err = integrate.quad(f, a, b)
print("Check for the simpsone method = ", round(v, 3))
# Out:
# Simpsone method: 0.249
# Check for the simpsone method =  0.249
