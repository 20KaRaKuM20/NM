# %% [markdown]
# <a href="https://colab.research.google.com/github/20KaRaKuM20/NM/blob/main/%D0%BB%D1%805_%D0%92%D0%B8%D1%81%D0%BE%D1%86%D1%8C%D0%BA%D0%B8%D0%B9_%D0%92%D0%BE%D0%BB%D0%BE%D0%B4%D0%B8%D0%BC%D0%B8%D1%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Побудова графіка функції
import numpy as np
import matplotlib.pyplot as plt

# область значень для x та y
x_min, x_max = -2, 2
y_min, y_max = -1, 3
step = 0.01

# створюємо масиви значень x та y
x_range = np.arange(x_min, x_max, step)
y_range = np.arange(y_min, y_max, step)
X, Y = np.meshgrid(x_range, y_range)

# рівняння системи
eq1 = np.sin(X) + 2*Y - 2
eq2 = np.cos(Y - 1) + X - 0.7
# створюємо графік
fig, ax = plt.subplots(figsize=(8, 8))
# додаємо графік першого рівняння
ax.contour(X, Y, eq1, levels=[0], colors='red')
# додаємо графік другого рівняння
ax.contour(X, Y, eq2, levels=[0], colors='blue')
# налаштування графіка
ax.set_xlim([x_min, x_max])
ax.set_ylim([y_min, y_max])
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Графік системи рівнянь')
# показуємо графік
plt.grid(True)
plt.show()

# %%
#Розв'язок системи рівнянь методом простої ітерації
import numpy as np
from scipy import optimize
import math

x0 = 0.0
y0 = 1.0

def f1(y):
    return 0.7 - math.cos(y - 1)

def f2(x):
    return 1 - 0.5 * math.sin(x)

def iter_method(x_start, y_start, e):
    xn = x_start
    yn = y_start

    xn1 = f1(yn)
    yn1 = f2(xn)
    n = 1

    while (abs(xn1 - xn) > e) or (abs(yn1 - yn) > e):
        xn = xn1
        yn = yn1
        xn1 = f1(yn)
        yn1 = f2(xn)
        n += 1

    print('Simple iteration:')
    print(f'x = {xn1:.6f}')
    print(f'y = {yn1:.6f}')
    print(f'The amount of iterations = {n}')

iter_method(x0, y0, 0.0001)

def f3(vars):
    x_val, y_val = vars

    return [math.sin(x_val) + 2*y_val - 2,
            math.cos(y_val - 1) + x_val - 0.7]


s = optimize.root(f3, [0, 0], method='hybr')

print('\nCheck (scipy.root):')
print(f'x = {s.x[0]:.6f}')
print(f'y = {s.x[1]:.6f}')
# Out:
# Simple iteration:
# x = -0.289806
# y = 1.142908
# The amount of iterations = 7
#
# Check (scipy.root):
# x = -0.289809
# y = 1.142885
