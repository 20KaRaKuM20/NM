# %% [markdown]
# <a href="https://colab.research.google.com/github/20KaRaKuM20/NM/blob/main/%D0%BB%D1%806_%D0%92%D0%B8%D1%81%D0%BE%D1%86%D1%8C%D0%BA%D0%B8%D0%B9_%D0%92%D0%BE%D0%BB%D0%BE%D0%B4%D0%B8%D0%BC%D0%B8%D1%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sympy import symbols, expand
from scipy.interpolate import lagrange

# %%
x = np.array([-2., -1., 1., 2.], dtype=float)
y = np.array([-26., -5., 1., 10.], dtype=float)

x1 = -0.5  # точка, в якій потрібно обчислити значення
x2 = 0.5
x3 = 1.5
x4 = 2.5

def lagrange_interpolation(x, y, x_test):
    n = len(x)
    p = np.zeros(n)  # масив для зберігання значень багаточленів L_i

    for i in range(n):
        # обчислюємо багаточлен L_i
        p_i = 1
        for j in range(n):
            if i != j:
                p_i *= (x_test - x[j]) / (x[i] - x[j])
        p[i] = p_i

    return np.dot(y, p)  # повертаємо значення багаточлена (сума y_i * L_i)

# Обчислюємо інтерполяційний багаточлен та його значення у точках
f1 = lagrange_interpolation(x, y, x1)
print("Значення функції у точці x_1 =", f1.round(4))

f2 = lagrange_interpolation(x, y, x2)
print("Значення функції у точці x_2 =", f2.round(4))

f3 = lagrange_interpolation(x, y, x3)
print("Значення функції у точці x_3 =", f3.round(4))

f4 = lagrange_interpolation(x, y, x4)
print("Значення функції у точці x_4 =", f4.round(4))
# Out:
# Значення функції у точці x_1 = -1.25
# Значення функції у точці x_2 = 0.25
# Значення функції у точці x_3 = 3.75
# Значення функції у точці x_4 = 21.25

# %%
xnew=np.linspace(np.min(x),np.max(x),100) #точки, за якими будуємо графік
ynew=[lagrange_interpolation(x,y,i) for i in xnew]
plt.plot(x,y,'o',xnew,ynew) #будуємо графік функції Лагранжа
plt.plot(x1,f1,'ro')
plt.plot(x2,f2,'ro')
plt.plot(x3,f3,'ro')
plt.plot(x4,f4,'ro')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Lagrange Polynomial_1')
plt.grid(True)
plt.show()

# %%
#Перевірка
f = lagrange(x, y)
fig = plt.figure(figsize = (7,5))
plt.plot(xnew, f(xnew), 'b', x, y, 'ro')
plt.title('Lagrange Polynomial_2')
plt.plot(x1,f1,'o')
plt.plot(x2,f2,'o')
plt.plot(x3,f3,'o')
plt.plot(x4,f4,'o')
plt.grid()
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Вузли інтерполяції
x = np.array([1.1, 1.24, 1.38], dtype=float)

def f_x(x):
    return (x + 1) / (3 + np.sqrt(x) + np.log10(x))

# Обчислюємо значення функції у вузлах
y_data = f_x(x)

print('x =', x)
print('f_x(x) =', y_data)
print('shapes:', x.shape, y_data.shape)

# Інтерполяційний поліном Лагранжа
p = lagrange(x, y_data)
print('Поліном Лагранжа p(x):')
print(p)
print('Ступінь полінома:', p.order)

# Точки для графіка
z = np.linspace(np.min(x), np.max(x), 100)

# Графік
plt.plot(z, p(z), '-', label='$L(x)$')
plt.plot(x, y_data, 'o', label='data')
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# x = [1.1  1.24 1.38]
# f_x(x) = [0.51342213 0.53244914 0.55161377]
# shapes: (3,) (3,)
# Поліном Лагранжа p(x):
#           2
# 0.003511 x + 0.1277 x + 0.3687
# Ступінь полінома: 2

# %%
import numpy as np

# Вузли інтерполяції
x = np.array([1.1, 1.24, 1.38], dtype=float)

def f_x(x):
    return (x + 1) / (3 + np.sqrt(x) + np.log10(x))

# Значення функції у вузлах
y_data = f_x(x)

# Точка, у якій інтерполюємо
x_1 = 1.15

def lagrange_interpolation(x, y, x_test):
    n = len(x)
    total = 0.0
    for i in range(n):
        l_i = 1.0
        for j in range(n):
            if i != j:
                l_i *= (x_test - x[j]) / (x[i] - x[j])
        total += y[i] * l_i
    return total

# Значення інтерполяційного полінома у x_1
f1 = lagrange_interpolation(x, y_data, x_1)

print("Значення інтерполяції у точці x_1 =", np.round(f1, 6))
# Out:
# Значення інтерполяції у точці x_1 = 0.520202
